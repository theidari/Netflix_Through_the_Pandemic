# %%
import pandas as pd

df = pd.read_csv(r'/content/abcdata.csv')
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0     1/2/2019  259.279999  269.750000  256.579987  267.660004  267.660004
# 1     1/3/2019  270.200012  275.790009  264.429993  271.200012  271.200012
# 2     1/4/2019  281.880005  297.799988  278.540009  297.570007  297.570007
# 3     1/7/2019  302.100006  316.799988  301.649994  315.339996  315.339996
# 4     1/8/2019  319.980011  320.589996  308.010010  320.269989  320.269989
# ..         ...         ...         ...         ...         ...         ...
# 858  5/27/2022  193.190002  195.250000  190.369995  195.190002  195.190002
# 859  5/31/2022  196.179993  199.949997  190.800003  197.440002  197.440002
# 860   6/1/2022  198.699997  202.740005  191.660004  192.910004  192.910004
# 861   6/2/2022  192.020004  205.470001  191.720001  205.089996  205.089996
# 862   6/3/2022  200.139999  202.949997  198.050003  198.979996  198.979996
#
#        Volume
# 0    11679500
# 1    14969600
# 2    19330100
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Date'],df['Open'],color = 'g',s = 100)
plt.xticks(rotation = 25)
plt.xlabel('Date')
plt.ylabel('Open')
# Out:
# Text(0, 0.5, 'Open')

# %%
fig = plt.figure()
ax1 = fig.add_subplot()
ax1.scatter(df['Date'], df['Open'], s=10, c='b', marker="s", label='Open')
plt.xlabel('Date')
plt.ylabel('Open')
plt.legend(loc='upper left')
plt.show()

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot()
ax2.scatter(df['Date'],df['High'], s=10, c='r', marker="o", label='High')
plt.xlabel('Date')
plt.ylabel('High')
plt.legend(loc='upper left')
plt.show()

# %%
fig3 = plt.figure()
ax3 = fig3.add_subplot()
ax3.scatter(df['Date'],df['Low'], s=10, c='y', marker="o", label='Low')
plt.xlabel('Date')
plt.ylabel('Low')
plt.legend(loc='upper left')
plt.show()

# %%
fig4 = plt.figure()
ax4= fig4.add_subplot()
ax4.scatter(df['Date'],df['Close'], s=10, c='g', marker="o", label='Close')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend(loc='upper left')
plt.show()

# %%
fig5 = plt.figure()
ax5 = fig5.add_subplot()
ax5.scatter(df['Date'],df['Adj Close'], s=10, c='#1f77b4', marker="o", label='Adj Close')
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.legend(loc='upper left')
plt.show()

# %%
fig6 = plt.figure()
ax6 = fig6.add_subplot()
ax6.scatter(df['Date'],df['Volume'], s=10, c='#9467bd', marker="o", label='Volume')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend(loc='upper left')
plt.show()

# %%
coor_p=df[['Open',	'High',	'Low'	, 'Close','Volume']].corr(method='pearson')
print("Correlation between all variables\n",coor_p)
# Out:
# Correlation between all variables
#              Open      High       Low     Close    Volume
# Open    1.000000  0.998679  0.998670  0.997087 -0.343699
# High    0.998679  1.000000  0.998357  0.998676 -0.333467
# Low     0.998670  0.998357  1.000000  0.998634 -0.358658
# Close   0.997087  0.998676  0.998634  1.000000 -0.344892
# Volume -0.343699 -0.333467 -0.358658 -0.344892  1.000000

# %%
import seaborn as sns
sns.heatmap(coor_p)
